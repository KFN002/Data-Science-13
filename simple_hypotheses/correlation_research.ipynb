# %%
from utils.preformatting_data import *
import pandas as pd
from scipy.stats import pearsonr, spearmanr

data = preformat(pd.read_csv('../medics_1.csv', delimiter=',', encoding='utf-8'))

columns_to_research = [
    "возраст",
    "сад",
    "дад",
    "чсс",
    "рн",
    "фракция_изгнания",
    "холестерин",
    "креатинин_крови",
    "мочевина",
    "скф_расч",
    "калий",
    "имт",
    "толщина_паренхимы_почек",
    "количество_шунтов",
    "длительность_аик",
    "длительность_операции",
    "время_пережатия_аорты",
    "объем_кровопотерии",
    "объем_гемотрансфузии",
    "объем_инфузий",
    "диурез"
]

df_new = data[columns_to_research]  # отбираем столбцы для рассчётов

crosstab = df_new.corr()  # создаём таблицу корреляций

correlations = []

# отбираем ячейки с корреляцией более 0.2
for x in columns_to_research:
    for y in columns_to_research:
        cell = crosstab[x][y]

        if cell >= 0.5 and cell != 1:
            correlations.append([x, y, cell])

correlations = sorted(correlations, key=lambda x: x[2], reverse=True)

correlations = correlations[::2]


print(crosstab)
# Out:
#                           возраст       сад       дад       чсс        рн  \
# возраст                  1.000000  0.020420 -0.091122 -0.124632  0.140034
# сад                      0.020420  1.000000  0.582127 -0.103752 -0.098058
# дад                     -0.091122  0.582127  1.000000  0.060398 -0.143108
# чсс                     -0.124632 -0.103752  0.060398  1.000000  0.000423
# рн                       0.140034 -0.098058 -0.143108  0.000423  1.000000
# фракция_изгнания         0.019036  0.087648  0.090065 -0.045378 -0.077689
# холестерин               0.014950  0.110062  0.269913  0.051210 -0.071264
# креатинин_крови          0.194855  0.175545  0.156227 -0.159604  0.047350
# мочевина                 0.187667  0.136517  0.136898 -0.079224  0.013056
# скф_расч                -0.566351 -0.179304 -0.134303  0.215381  0.014740
# калий                   -0.052293 -0.011764  0.103808  0.078366 -0.169095
# имт                     -0.108649  0.029024  0.046007  0.143646  0.055225
# толщина_паренхимы_почек -0.094236 -0.102044 -0.071387  0.049760  0.066443
# количество_шунтов        0.135951  0.033260 -0.010136 -0.005223  0.065058
# длительность_аик         0.068455 -0.028149 -0.115264  0.032939  0.042101
# длительность_операции    0.140030 -0.018493  0.003674  0.014828  0.060889
# время_пережатия_аорты    0.092687 -0.009335 -0.033621  0.021798  0.026337
# объем_кровопотерии       0.034062  0.065000  0.063649  0.064156 -0.063820
# объем_гемотрансфузии     0.259891 -0.173037 -0.084143 -0.048800  0.086553
# объем_инфузий            0.009784 -0.100180  0.001224  0.059439  0.013935
# диурез                  -0.068043 -0.139628 -0.061580  0.074558  0.114308
#
#                          фракция_изгнания  холестерин  креатинин_крови  \
# возраст                          0.019036    0.014950         0.194855
# сад                              0.087648    0.110062         0.175545
# дад                              0.090065    0.269913         0.156227
# чсс                             -0.045378    0.051210        -0.159604
# рн                              -0.077689   -0.071264         0.047350
# фракция_изгнания                 1.000000    0.014600        -0.105243
# холестерин                       0.014600    1.000000         0.076541
# креатинин_крови                 -0.105243    0.076541         1.000000
# мочевина                        -0.136028    0.155788         0.612396
# скф_расч                        -0.118418   -0.057232        -0.613252
# калий                            0.021966    0.025827         0.004267
# имт                             -0.017001   -0.000408        -0.135835
# толщина_паренхимы_почек         -0.029746   -0.067763        -0.209041
# количество_шунтов               -0.100678    0.045803        -0.127279
# длительность_аик                -0.156339   -0.097905        -0.113297
# длительность_операции           -0.134036    0.115779        -0.101270
# время_пережатия_аорты           -0.082840   -0.043150        -0.099640
# объем_кровопотерии              -0.117822   -0.080942        -0.068060
# объем_гемотрансфузии            -0.039702    0.008150        -0.106977
# объем_инфузий                    0.012547   -0.021185         0.119955
# диурез                          -0.030000   -0.152406        -0.109603
#
#                          мочевина  скф_расч  ...       имт  \
# возраст                  0.187667 -0.566351  ... -0.108649
# сад                      0.136517 -0.179304  ...  0.029024
# дад                      0.136898 -0.134303  ...  0.046007
# чсс                     -0.079224  0.215381  ...  0.143646
# рн                       0.013056  0.014740  ...  0.055225
# фракция_изгнания        -0.136028 -0.118418  ... -0.017001
# холестерин               0.155788 -0.057232  ... -0.000408
# креатинин_крови          0.612396 -0.613252  ... -0.135835
# мочевина                 1.000000 -0.402487  ... -0.123311
# скф_расч                -0.402487  1.000000  ...  0.514295
# калий                    0.081118 -0.036473  ... -0.013572
# имт                     -0.123311  0.514295  ...  1.000000
# толщина_паренхимы_почек -0.224708  0.273438  ...  0.206569
# количество_шунтов       -0.187981 -0.051623  ... -0.073642
# длительность_аик        -0.010835  0.029563  ... -0.084795
# длительность_операции   -0.130052  0.013261  ...  0.083364
# время_пережатия_аорты   -0.069137 -0.042622  ... -0.124565
# объем_кровопотерии       0.027147 -0.023186  ... -0.004622
# объем_гемотрансфузии    -0.082595 -0.181342  ... -0.172771
# объем_инфузий           -0.001217 -0.012625  ...  0.133164
# диурез                  -0.175230  0.031675  ... -0.128343
#
#                          толщина_паренхимы_почек  количество_шунтов  \
# возраст                                -0.094236           0.135951
# сад                                    -0.102044           0.033260
# дад                                    -0.071387          -0.010136
# чсс                                     0.049760          -0.005223
# рн                                      0.066443           0.065058
# фракция_изгнания                       -0.029746          -0.100678
# холестерин                             -0.067763           0.045803
# креатинин_крови                        -0.209041          -0.127279
# мочевина                               -0.224708          -0.187981
# скф_расч                                0.273438          -0.051623
# калий                                   0.087081           0.068600
# имт                                     0.206569          -0.073642
# толщина_паренхимы_почек                 1.000000           0.031773
# количество_шунтов                       0.031773           1.000000
# длительность_аик                        0.064915           0.510360
# длительность_операции                  -0.003524           0.589465
# время_пережатия_аорты                   0.083964           0.620071
# объем_кровопотерии                      0.066922           0.092362
# объем_гемотрансфузии                    0.099777           0.413412
# объем_инфузий                           0.080824          -0.145692
# диурез                                  0.051028           0.246643
#
#                          длительность_аик  длительность_операции  \
# возраст                          0.068455               0.140030
# сад                             -0.028149              -0.018493
# дад                             -0.115264               0.003674
# чсс                              0.032939               0.014828
# рн                               0.042101               0.060889
# фракция_изгнания                -0.156339              -0.134036
# холестерин                      -0.097905               0.115779
# креатинин_крови                 -0.113297              -0.101270
# мочевина                        -0.010835              -0.130052
# скф_расч                         0.029563               0.013261
# калий                            0.083020              -0.010333
# имт                             -0.084795               0.083364
# толщина_паренхимы_почек          0.064915              -0.003524
# количество_шунтов                0.510360               0.589465
# длительность_аик                 1.000000               0.385593
# длительность_операции            0.385593               1.000000
# время_пережатия_аорты            0.900344               0.457819
# объем_кровопотерии               0.491905               0.129796
# объем_гемотрансфузии             0.394786               0.325026
# объем_инфузий                   -0.501877               0.109665
# диурез                           0.377304               0.223238
#
#                          время_пережатия_аорты  объем_кровопотерии  \
# возраст                               0.092687            0.034062
# сад                                  -0.009335            0.065000
# дад                                  -0.033621            0.063649
# чсс                                   0.021798            0.064156
# рн                                    0.026337           -0.063820
# фракция_изгнания                     -0.082840           -0.117822
# холестерин                           -0.043150           -0.080942
# креатинин_крови                      -0.099640           -0.068060
# мочевина                             -0.069137            0.027147
# скф_расч                             -0.042622           -0.023186
# калий                                 0.111752            0.138877
# имт                                  -0.124565           -0.004622
# толщина_паренхимы_почек               0.083964            0.066922
# количество_шунтов                     0.620071            0.092362
# длительность_аик                      0.900344            0.491905
# длительность_операции                 0.457819            0.129796
# время_пережатия_аорты                 1.000000            0.459006
# объем_кровопотерии                    0.459006            1.000000
# объем_гемотрансфузии                  0.453453            0.200586
# объем_инфузий                        -0.476867           -0.153663
# диурез                                0.344797            0.197220
#
#                          объем_гемотрансфузии  объем_инфузий    диурез
# возраст                              0.259891       0.009784 -0.068043
# сад                                 -0.173037      -0.100180 -0.139628
# дад                                 -0.084143       0.001224 -0.061580
# чсс                                 -0.048800       0.059439  0.074558
# рн                                   0.086553       0.013935  0.114308
# фракция_изгнания                    -0.039702       0.012547 -0.030000
# холестерин                           0.008150      -0.021185 -0.152406
# креатинин_крови                     -0.106977       0.119955 -0.109603
# мочевина                            -0.082595      -0.001217 -0.175230
# скф_расч                            -0.181342      -0.012625  0.031675
# калий                                0.092516      -0.004472  0.040510
# имт                                 -0.172771       0.133164 -0.128343
# толщина_паренхимы_почек              0.099777       0.080824  0.051028
# количество_шунтов                    0.413412      -0.145692  0.246643
# длительность_аик                     0.394786      -0.501877  0.377304
# длительность_операции                0.325026       0.109665  0.223238
# время_пережатия_аорты                0.453453      -0.476867  0.344797
# объем_кровопотерии                   0.200586      -0.153663  0.197220
# объем_гемотрансфузии                 1.000000      -0.025755  0.257814
# объем_инфузий                       -0.025755       1.000000 -0.010843
# диурез                               0.257814      -0.010843  1.000000
#
# [21 rows x 21 columns]

# %%
print(["фактор1", "фактор2", "корреляция"])
print(*correlations, sep="\n")
# Out:
# ['фактор1', 'фактор2', 'корреляция']
# ['длительность_аик', 'время_пережатия_аорты', 0.9003435304377455]
# ['количество_шунтов', 'время_пережатия_аорты', 0.6200713806266671]
# ['креатинин_крови', 'мочевина', 0.6123963707140346]
# ['количество_шунтов', 'длительность_операции', 0.5894649921982215]
# ['сад', 'дад', 0.5821269994760774]
# ['скф_расч', 'имт', 0.5142950927003834]
# ['количество_шунтов', 'длительность_аик', 0.5103597305171141]

# %%
# получаем p-value для факторов с наибольшей корреляцией
res = []

for fac1, fac2, corr in correlations:
    res.append([fac1, fac2, corr, pearsonr(data[fac1], data[fac2]).pvalue])

print(["фактор1", "фактор2", "корреляция", "p-value"])
print(*res, sep="\n")
# Out:
# ['фактор1', 'фактор2', 'корреляция', 'p-value']
# ['длительность_аик', 'время_пережатия_аорты', 0.9003435304377455, 6.993373227871792e-58]
# ['количество_шунтов', 'время_пережатия_аорты', 0.6200713806266671, 4.7327351704677334e-18]
# ['креатинин_крови', 'мочевина', 0.6123963707140346, 1.5619558227364968e-17]
# ['количество_шунтов', 'длительность_операции', 0.5894649921982215, 4.593629804366926e-16]
# ['сад', 'дад', 0.5821269994760774, 1.2821930198709196e-15]
# ['скф_расч', 'имт', 0.5142950927003834, 5.593224509466298e-12]
# ['количество_шунтов', 'длительность_аик', 0.5103597305171141, 8.607445801968889e-12]
